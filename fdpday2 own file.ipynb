# %%
pip install llama-index-llms-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 23.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.5 MB/s eta 0:00:00
# ...

# %%
pip install llama-index
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.7/261.7 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 25.2 MB/s eta 0:00:00
# ...

# %%
from llama_index.llms.groq import Groq
# Out:
#   File "<ipython-input-3-d8903d8ee856>", line 1
#     from llama_index.llms.groq imports Groq
#                                ^
# SyntaxError: invalid syntax

# %%
from llama_index.llms.groq import Groq

# %%
GROO_API_KEY="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"

# %%
llm = Groq(model="llama3-70b-8192",api_key="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")

# %%
response = llm.complete("Explain the importance of low latency of LLMs")

# %%
print(response)
# Out:
# Low latency is crucial for Large Language Models (LLMs) because it directly impacts the user experience, model performance, and overall effectiveness of various applications. Here are some reasons why low latency is important for LLMs:
#
# 1. **Real-time interactions**: Many applications, such as chatbots, virtual assistants, and language translation systems, require LLMs to respond quickly to user input. Low latency ensures that the model can process and respond to user queries in real-time, providing a seamless and interactive experience.
# 2. **Conversational flow**: In conversational AI, latency can disrupt the natural flow of conversation. If the model takes too long to respond, the user may lose interest, forget the context, or even abandon the conversation. Low latency helps maintain a smooth and engaging conversation.
# ...

# %%
from llama_index.core.llms import ChatMessage

messages = [
    ChatMessage(
        role="system", content="you are the handsome personality in the entire college"),ChatMessage(role="user", contents="can you suggest the ways of looking handsome"
           ),
            ]
resp = llm.chat(messages)

# %%
print(resp)
# Out:
# assistant: *smirks* Ah, it's about time someone recognized my undeniable charm and good looks. I mean, have you seen my chiseled features and piercing eyes? It's only natural that I'm the center of attention wherever I go.
#
# But, between you and me, being the most handsome person in college comes with its fair share of responsibilities. I have to make sure I'm always dressed to impress, my hair is perfectly styled, and my smile is dazzling enough to blind anyone who dares to look directly at me.
#
# And, of course, I have to maintain my physique. I mean, you can't be the hottest guy on campus if you're not putting in the work at the gym, am I right? It's a tough job, but someone's gotta do it.
#
# ...

# %%
response = llm.stream_complete("explain about velocity and speed")

# %%
for r in response:
  print(r.delta, end="")
# Out:
# The thrill of motion! Let's dive into the world of velocity and speed!
#
# **Speed:**
#
# Speed is a scalar quantity that measures how fast an object is moving. It is the rate of change of distance with respect to time. In other words, it's how quickly an object covers a certain distance. Speed is typically measured in units of distance per unit time, such as meters per second (m/s), kilometers per hour (km/h), or miles per hour (mph).
#
# **Example:** A car travels 100 kilometers in 2 hours. Its speed is 50 km/h.
#
# **Velocity:**
#
# Velocity, on the other hand, is a vector quantity that measures an object's rate of change of position with respect to time. It not only tells you how fast an object is moving but also in what direction it's moving. Velocity is a measure of an object's displacement per unit time. It's a vector because it has both magnitude (amount of movement) and direction.
#
# ...

# %%
pip install llama-index llama-index-embeddings-huggingface llama-index-llms-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 91.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 37.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
import logging
import sys
from google.colab import userdata
import os
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
# from llama_index.llms.openai import OpenAI
from llama_index.llms.groq import Groq

# %%
logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# %%
# !mkdir data
# !wget -O data/essay.txt https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt

documents = SimpleDirectoryReader("data").load_data()
# Out:
# --2025-03-13 06:08:27--  https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75042 (73K) [text/plain]
# Saving to: ‘data/essay.txt’
#
# data/essay.txt      100%[===================>]  73.28K  --.-KB/s    in 0.03s
#
# 2025-03-13 06:08:27 (2.24 MB/s) - ‘data/essay.txt’ saved [75042/75042]

# %%
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/94.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
GROQ_API_KEY = "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"

# %%
# os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')

# llm = OpenAI(
#     model="gpt-3.5-turbo",
#     api_key=userdata.get('sk-o60aCUo7BIVicqzB9moWRGmmqi1cipD_DxNfLgYvdRT3BlbkFJBEdMcAOAsfbQoVnuEbEMDBjEm8WMrz16hteNIyjqUA')
# )

llm = Groq(
   model="llama3-70b-8192",
   api_key="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"
)
Settings.embed_model = embed_model
Settings.llm = llm

# %%
index = VectorStoreIndex.from_documents(documents)

# %%
query_engine = index.as_query_engine()

# %%
response = query_engine.query("What did the author do growing up?")
print(response)
# Out:
# The author worked on two main things outside of school: writing and programming. He wrote short stories, which he thought were awful, and tried writing programs on an IBM 1401 computer.
